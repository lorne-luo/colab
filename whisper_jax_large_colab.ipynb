# %% [markdown]
# <a href="https://colab.research.google.com/github/lorne-luo/colab/blob/main/whisper_jax_large_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# https://github.com/sanchit-gandhi/whisper-jax/blob/main/README.md modified

# !pip install -U "jax[cuda11_local]==0.4.13" "jaxlib[cuda11_local]==0.4.13" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# !pip install -q git+https://github.com/camenduru/whisper-jax.git datasets soundfile librosa yt_dlp cached_property
# Out:
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# Collecting jax[cuda11_local]==0.4.13
#   Downloading jax-0.4.13.tar.gz (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 18.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting jaxlib[cuda11_local]==0.4.13
#   Downloading https://storage.googleapis.com/jax-releases/cuda12/jaxlib-0.4.13%2Bcuda12.cudnn89-cp310-cp310-manylinux2014_x86_64.whl (188.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.5/188.5 MB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: ml-dtypes>=0.1.0 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_local]==0.4.13) (0.2.0)
# Requirement already satisfied: numpy>=1.21 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_local]==0.4.13) (1.23.5)
# Requirement already satisfied: opt-einsum in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_local]==0.4.13) (3.3.0)
# Requirement already satisfied: scipy>=1.7 in /usr/local/lib/python3.10/dist-packages (from jax[cuda11_local]==0.4.13) (1.11.2)
# Collecting jaxlib==0.4.13+cuda11.cudnn86 (from jax[cuda11_local]==0.4.13)
#   Downloading https://storage.googleapis.com/jax-releases/cuda11/jaxlib-0.4.13%2Bcuda11.cudnn86-cp310-cp310-manylinux2014_x86_64.whl (188.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.3/188.3 MB 6.2 MB/s eta 0:00:00
# WARNING: jaxlib 0.4.13+cuda12.cudnn89 does not provide the extra 'cuda11_local'
# INFO: pip is looking at multiple versions of jaxlib[cuda11-local] to determine which version is compatible with other requirements. This could take a while.
# WARNING: jaxlib 0.4.13+cuda11.cudnn86 does not provide the extra 'cuda11_local'
# Building wheels for collected packages: jax
#   Building wheel for jax (pyproject.toml) ... done
#   Created wheel for jax: filename=jax-0.4.13-py3-none-any.whl size=1518704 sha256=0470c9c8abfebbd7888efc022d6b1097602ea62d89f4cc72de9f4e0383b81503
#   Stored in directory: /root/.cache/pip/wheels/f3/7a/25/f297f69029b5e4064e4736a0c4b3996a44cc27781c120bcb99
# Successfully built jax
# Installing collected packages: jaxlib, jax
#   Attempting uninstall: jaxlib
#     Found existing installation: jaxlib 0.4.14+cuda11.cudnn86
#     Uninstalling jaxlib-0.4.14+cuda11.cudnn86:
#       Successfully uninstalled jaxlib-0.4.14+cuda11.cudnn86
#   Attempting uninstall: jax
#     Found existing installation: jax 0.4.14
#     Uninstalling jax-0.4.14:
#       Successfully uninstalled jax-0.4.14
# Successfully installed jax-0.4.13 jaxlib-0.4.13+cuda11.cudnn86
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 8.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 64.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 66.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 14.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 22.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 15.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.4/194.4 kB 18.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 77.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.9/129.9 kB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 75.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 103.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 91.3 MB/s eta 0:00:00
#   Building wheel for whisper-jax (pyproject.toml) ... done

# %%
import jax
from whisper_jax import FlaxWhisperPipline
import jax.numpy as jnp

pipeline = FlaxWhisperPipline("openai/whisper-medium", dtype=jnp.float16)
from jax.experimental.compilation_cache import compilation_cache as cc
cc.initialize_cache("/content/jax_cache")
# Out:
# Downloading (…)rocessor_config.json:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/805 [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/836k [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.48M [00:00<?, ?B/s]
# Downloading (…)olve/main/merges.txt:   0%|          | 0.00/494k [00:00<?, ?B/s]
# Downloading (…)main/normalizer.json:   0%|          | 0.00/52.7k [00:00<?, ?B/s]
# Downloading (…)in/added_tokens.json:   0%|          | 0.00/34.6k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/2.08k [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.99k [00:00<?, ?B/s]
# Downloading flax_model.msgpack:   0%|          | 0.00/3.06G [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/3.69k [00:00<?, ?B/s]
# WARNING:jax._src.compilation_cache:Initialized persistent compilation cache at /content/jax_cache

# %%
from yt_dlp import YoutubeDL
with YoutubeDL({'overwrites':True, 'format':'bestaudio[ext=m4a]', 'outtmpl':'/content/audio.m4a'}) as ydl:
    ydl.download("https://youtu.be/iJL7wBl2QqY")
# Out:
# [youtube] Extracting URL: https://youtu.be/iJL7wBl2QqY
# [youtube] iJL7wBl2QqY: Downloading webpage
# [youtube] iJL7wBl2QqY: Downloading ios player API JSON
# [youtube] iJL7wBl2QqY: Downloading android player API JSON
# [youtube] iJL7wBl2QqY: Downloading m3u8 information
# [info] iJL7wBl2QqY: Downloading 1 format(s): 140
# [download] Destination: /content/audio.m4a
# [download] 100% of    4.18MiB in 00:00:00 at 19.62MiB/s
# [FixupM4a] Correcting container of "/content/audio.m4a"

# %%
from datetime import datetime
outputs = pipeline("/content/audio.m4a", return_timestamps=True)
text = outputs["text"]
chunks = outputs["chunks"]
print(datetime.now()-start)
print(text)
# Out:
# Whisper did not predict an ending timestamp, which can happen if audio is cut off in the middle of a word. Also make sure WhisperTimeStampLogitsProcessor was used during generation.
